# %% [markdown]
# <a href="https://colab.research.google.com/github/liuzhengcai/tflearning/blob/master/start01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.optimizers import SGD
from keras.utils import np_utils

# %%
np.random.seed(1671)

# %%
NB_EPOCH=250
BATCH_SIZE=128
VERBOSE=1
NB_CLASSES=10
OPTMIZER=SGD()
N_HIDDEN=128
VALIDATION_SPLIT=0.2
DROP_OUT=0.3

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
RESHAPE=784
x_train=x_train.reshape(60000,RESHAPE)
x_test=x_test.reshape(10000,RESHAPE)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0],'train samples')
print(x_test.shape[0],'test samples')
y_train=np_utils.to_categorical(y_train,NB_CLASSES)
y_test=np_utils.to_categorical(y_test,NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %%
model=Sequential()
model.add(Dense(N_HIDDEN,input_shape=(RESHAPE,)))
model.add(Activation('relu'))
model.add(Dropout(DROP_OUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROP_OUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_8 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer=OPTMIZER,metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,batch_size=BATCH_SIZE,epochs=NB_EPOCH,verbose=VERBOSE,validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/250
# 400/400 [==============================] - 2s 5ms/step - loss: 1.9840 - accuracy: 0.3149 - val_loss: 0.8398 - val_accuracy: 0.8112
# Epoch 2/250
# 400/400 [==============================] - 2s 5ms/step - loss: 0.9746 - accuracy: 0.6957 - val_loss: 0.5198 - val_accuracy: 0.8673
# Epoch 3/250
# 400/400 [==============================] - 2s 5ms/step - loss: 0.7046 - accuracy: 0.7808 - val_loss: 0.4169 - val_accuracy: 0.8911
# Epoch 4/250
# 400/400 [==============================] - 2s 5ms/step - loss: 0.5929 - accuracy: 0.8230 - val_loss: 0.3633 - val_accuracy: 0.9023
# Epoch 5/250
# 400/400 [==============================] - 2s 5ms/step - loss: 0.5281 - accuracy: 0.8399 - val_loss: 0.3290 - val_accuracy: 0.9112
# Epoch 6/250
# 400/400 [==============================] - 2s 5ms/step - loss: 0.4820 - accuracy: 0.8584 - val_loss: 0.3076 - val_accuracy: 0.9137
# Epoch 7/250
# ...

# %%
score=model.evaluate(x_test,y_test,verbose=VERBOSE)
print("test score",score[0])
print("test accuracy",score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0733 - accuracy: 0.9774
# test score 0.07326957583427429
# test accuracy 0.977400004863739
